# %% [markdown]
# # Author : Sarthak Kumar Rath

# %% [markdown]
# # Data Science Internship @LetsGrowMore

# %% [markdown]
# # Image to Pencil Sketch with Python

# %% [markdown]
# # Beginner Level Task(04)

# %% [markdown]
# # Description

# %% [markdown]
# We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.

# %% [markdown]
# # Importing Libraries

# %%
# !pip install opencv-python

# %%
#let's import the library

import cv2
import matplotlib.pyplot as plt

# %%
#lets read the image

img = cv2.imread("dog.jpg")

# %%
#get the image using matplotlib
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_img)
plt.plot()
# Out:
# []

# %% [markdown]
# # steps to convert an image to pencil sketch

# %% [markdown]
# 1) We need to read the image in RBG format and then convert it to a grayscale image.
#
# 2)  Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image.
#
# 3) Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image.

# %%
#let's convert the image into gray scale

gray_image = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
cv2.imshow("gray image",gray_image)

# %%
#let's invert the gray_image

inverted_gray_image = 255 - gray_image

# %%
#blur the image using gaussian blur

blurred_image = cv2.GaussianBlur(inverted_gray_image,(21,21),0)

# %%
# let's invert the blurred_image

inverted_blur = 255 - blurred_image

# %%
cv2.imshow("inverted blured",inverted_blur)

# %% [markdown]
# # finally let's create the pencil sketch image

# %%
pencil_sketch_image = cv2.divide(gray_image,inverted_blur,scale = 256.0)

# %%
#Let's show the sketch_image

cv2.imshow("original image",img)

# %%
cv2.imshow("pencil sketch image",pencil_sketch_image)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# # Let's Check all the images and the final pencil sketch image

# %% [markdown]
# # Thank you....
